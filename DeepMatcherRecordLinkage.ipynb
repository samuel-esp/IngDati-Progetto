# %% [markdown]
# # Deep Matcher - Record Linkage

# %%
# !pip install py_entitymatching #--quiet
# !pip install deepmatcher #--quiet
# Out:
# Requirement already satisfied: py_entitymatching in /opt/anaconda3/lib/python3.8/site-packages (0.4.0)
# Requirement already satisfied: pyparsing>=2.1.4 in /opt/anaconda3/lib/python3.8/site-packages (from py_entitymatching) (2.4.7)
# Requirement already satisfied: cloudpickle>=0.2.1 in /opt/anaconda3/lib/python3.8/site-packages (from py_entitymatching) (1.6.0)
# Requirement already satisfied: numpy in /opt/anaconda3/lib/python3.8/site-packages (from py_entitymatching) (1.20.1)
# Requirement already satisfied: ipython>=5.6 in /opt/anaconda3/lib/python3.8/site-packages (from py_entitymatching) (7.22.0)
# Requirement already satisfied: matplotlib>=2.2.4 in /opt/anaconda3/lib/python3.8/site-packages (from py_entitymatching) (3.3.4)
# Requirement already satisfied: requests in /opt/anaconda3/lib/python3.8/site-packages (from py_entitymatching) (2.25.1)
# Requirement already satisfied: scipy in /opt/anaconda3/lib/python3.8/site-packages (from py_entitymatching) (1.6.2)
# Requirement already satisfied: py-stringsimjoin>=0.3.0 in /opt/anaconda3/lib/python3.8/site-packages (from py_entitymatching) (0.3.2)
# Requirement already satisfied: PyPrind in /opt/anaconda3/lib/python3.8/site-packages (from py_entitymatching) (2.11.3)
# Requirement already satisfied: scikit-learn>=0.22 in /opt/anaconda3/lib/python3.8/site-packages (from py_entitymatching) (0.24.1)
# Requirement already satisfied: pygments in /opt/anaconda3/lib/python3.8/site-packages (from ipython>=5.6->py_entitymatching) (2.8.1)
# Requirement already satisfied: setuptools>=18.5 in /opt/anaconda3/lib/python3.8/site-packages (from ipython>=5.6->py_entitymatching) (52.0.0.post20210125)
# Requirement already satisfied: pexpect>4.3 in /opt/anaconda3/lib/python3.8/site-packages (from ipython>=5.6->py_entitymatching) (4.8.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /opt/anaconda3/lib/python3.8/site-packages (from ipython>=5.6->py_entitymatching) (3.0.17)
# Requirement already satisfied: pickleshare in /opt/anaconda3/lib/python3.8/site-packages (from ipython>=5.6->py_entitymatching) (0.7.5)
# Requirement already satisfied: appnope in /opt/anaconda3/lib/python3.8/site-packages (from ipython>=5.6->py_entitymatching) (0.1.2)
# Requirement already satisfied: traitlets>=4.2 in /opt/anaconda3/lib/python3.8/site-packages (from ipython>=5.6->py_entitymatching) (5.0.5)
# Requirement already satisfied: decorator in /opt/anaconda3/lib/python3.8/site-packages (from ipython>=5.6->py_entitymatching) (5.0.6)
# Requirement already satisfied: backcall in /opt/anaconda3/lib/python3.8/site-packages (from ipython>=5.6->py_entitymatching) (0.2.0)
# Requirement already satisfied: jedi>=0.16 in /opt/anaconda3/lib/python3.8/site-packages (from ipython>=5.6->py_entitymatching) (0.17.2)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in /opt/anaconda3/lib/python3.8/site-packages (from jedi>=0.16->ipython>=5.6->py_entitymatching) (0.7.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/anaconda3/lib/python3.8/site-packages (from matplotlib>=2.2.4->py_entitymatching) (1.3.1)
# Requirement already satisfied: pillow>=6.2.0 in /opt/anaconda3/lib/python3.8/site-packages (from matplotlib>=2.2.4->py_entitymatching) (8.2.0)
# Requirement already satisfied: python-dateutil>=2.1 in /opt/anaconda3/lib/python3.8/site-packages (from matplotlib>=2.2.4->py_entitymatching) (2.8.1)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/lib/python3.8/site-packages (from matplotlib>=2.2.4->py_entitymatching) (0.10.0)
# Requirement already satisfied: six in /opt/anaconda3/lib/python3.8/site-packages (from cycler>=0.10->matplotlib>=2.2.4->py_entitymatching) (1.15.0)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/anaconda3/lib/python3.8/site-packages (from pexpect>4.3->ipython>=5.6->py_entitymatching) (0.7.0)
# Requirement already satisfied: wcwidth in /opt/anaconda3/lib/python3.8/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.6->py_entitymatching) (0.2.5)
# Requirement already satisfied: pandas>=0.16.0 in /opt/anaconda3/lib/python3.8/site-packages (from py-stringsimjoin>=0.3.0->py_entitymatching) (1.2.4)
# Requirement already satisfied: joblib in /opt/anaconda3/lib/python3.8/site-packages (from py-stringsimjoin>=0.3.0->py_entitymatching) (1.0.1)
# Requirement already satisfied: py-stringmatching>=0.2.1 in /opt/anaconda3/lib/python3.8/site-packages (from py-stringsimjoin>=0.3.0->py_entitymatching) (0.4.2)
# Requirement already satisfied: pytz>=2017.3 in /opt/anaconda3/lib/python3.8/site-packages (from pandas>=0.16.0->py-stringsimjoin>=0.3.0->py_entitymatching) (2021.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/anaconda3/lib/python3.8/site-packages (from scikit-learn>=0.22->py_entitymatching) (2.1.0)
# Requirement already satisfied: ipython-genutils in /opt/anaconda3/lib/python3.8/site-packages (from traitlets>=4.2->ipython>=5.6->py_entitymatching) (0.2.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.8/site-packages (from requests->py_entitymatching) (2020.12.5)
# Requirement already satisfied: chardet<5,>=3.0.2 in /opt/anaconda3/lib/python3.8/site-packages (from requests->py_entitymatching) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/anaconda3/lib/python3.8/site-packages (from requests->py_entitymatching) (1.26.4)
# Requirement already satisfied: idna<3,>=2.5 in /opt/anaconda3/lib/python3.8/site-packages (from requests->py_entitymatching) (2.10)
# Requirement already satisfied: deepmatcher in /opt/anaconda3/lib/python3.8/site-packages (0.1.2.post2)
# Requirement already satisfied: torchtext>=0.9 in /opt/anaconda3/lib/python3.8/site-packages (from deepmatcher) (0.11.2)
# Requirement already satisfied: scikit-learn in /opt/anaconda3/lib/python3.8/site-packages (from deepmatcher) (0.24.1)
# Requirement already satisfied: pyprind in /opt/anaconda3/lib/python3.8/site-packages (from deepmatcher) (2.11.3)
# Requirement already satisfied: pandas in /opt/anaconda3/lib/python3.8/site-packages (from deepmatcher) (1.2.4)
# Requirement already satisfied: tqdm in /opt/anaconda3/lib/python3.8/site-packages (from deepmatcher) (4.59.0)
# Requirement already satisfied: nltk>=3.2.5 in /opt/anaconda3/lib/python3.8/site-packages (from deepmatcher) (3.6.1)
# Requirement already satisfied: six in /opt/anaconda3/lib/python3.8/site-packages (from deepmatcher) (1.15.0)
# Requirement already satisfied: fasttext in /opt/anaconda3/lib/python3.8/site-packages (from deepmatcher) (0.9.2)
# Requirement already satisfied: torch>=1.0 in /opt/anaconda3/lib/python3.8/site-packages (from deepmatcher) (1.10.2)
# Requirement already satisfied: dill in /opt/anaconda3/lib/python3.8/site-packages (from deepmatcher) (0.3.4)
# Requirement already satisfied: Cython in /opt/anaconda3/lib/python3.8/site-packages (from deepmatcher) (0.29.23)
# Requirement already satisfied: click in /opt/anaconda3/lib/python3.8/site-packages (from nltk>=3.2.5->deepmatcher) (7.1.2)
# Requirement already satisfied: regex in /opt/anaconda3/lib/python3.8/site-packages (from nltk>=3.2.5->deepmatcher) (2021.4.4)
# Requirement already satisfied: joblib in /opt/anaconda3/lib/python3.8/site-packages (from nltk>=3.2.5->deepmatcher) (1.0.1)
# Requirement already satisfied: typing-extensions in /opt/anaconda3/lib/python3.8/site-packages (from torch>=1.0->deepmatcher) (3.7.4.3)
# Requirement already satisfied: numpy in /opt/anaconda3/lib/python3.8/site-packages (from torchtext>=0.9->deepmatcher) (1.20.1)
# Requirement already satisfied: requests in /opt/anaconda3/lib/python3.8/site-packages (from torchtext>=0.9->deepmatcher) (2.25.1)
# Requirement already satisfied: setuptools>=0.7.0 in /opt/anaconda3/lib/python3.8/site-packages (from fasttext->deepmatcher) (52.0.0.post20210125)
# Requirement already satisfied: pybind11>=2.2 in /opt/anaconda3/lib/python3.8/site-packages (from fasttext->deepmatcher) (2.9.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /opt/anaconda3/lib/python3.8/site-packages (from pandas->deepmatcher) (2.8.1)
# Requirement already satisfied: pytz>=2017.3 in /opt/anaconda3/lib/python3.8/site-packages (from pandas->deepmatcher) (2021.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/anaconda3/lib/python3.8/site-packages (from requests->torchtext>=0.9->deepmatcher) (1.26.4)
# Requirement already satisfied: chardet<5,>=3.0.2 in /opt/anaconda3/lib/python3.8/site-packages (from requests->torchtext>=0.9->deepmatcher) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in /opt/anaconda3/lib/python3.8/site-packages (from requests->torchtext>=0.9->deepmatcher) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.8/site-packages (from requests->torchtext>=0.9->deepmatcher) (2020.12.5)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/anaconda3/lib/python3.8/site-packages (from scikit-learn->deepmatcher) (2.1.0)
# Requirement already satisfied: scipy>=0.19.1 in /opt/anaconda3/lib/python3.8/site-packages (from scikit-learn->deepmatcher) (1.6.2)

# %%
import sys
import py_entitymatching as em
import deepmatcher as dm
import os

# %%
# Load the two tables.
A = em.read_csv_metadata("alignedSchemas/companiesAligned.csv", key='id')
B = em.read_csv_metadata("alignedSchemas/companiesAligned.csv", key='id')
# Out:
# WARNING:py_entitymatching.io.parsers:Metadata file is not present in the given path; proceeding to read the csv file.
# WARNING:py_entitymatching.io.parsers:Metadata file is not present in the given path; proceeding to read the csv file.

# %%
# Basic information about the tables.
print('Number of tuples in A: ' + str(len(A)))
print('Number of tuples in B: ' + str(len(B)))
print('Number of tuples in A X B (i.e the cartesian product): ' + str(len(A)*len(B)))
# Out:
# Number of tuples in A: 64608
# Number of tuples in B: 64608
# Number of tuples in A X B (i.e the cartesian product): 4174193664

# %%
A.head()
# Out:
#    Unnamed: 0                   name  \
# 0           0                GROUPON
# 1           1         E-TECHNOLOGIES
# 2           2      YAKSHNA SOLUTIONS
# 3           3  THRU TUBING SOLUTIONS
# 4           4   CLEVELAND CLIFFS INC
#
#                                      headquarter        employees  \
# 0  600 W CHICAGO AVE SUITE 400 CHICAGO, IL 60616   1,001 TO 5,000
# 1                                       AUCKLAND          2 TO 10
# 2                                    HERNDON, VA         11 TO 50
# 3                                  OKLAHOMA CITY        51 TO 200
# 4                                  CLEVELAND, OH  5,001 TO 10,000
#
#                      industry website ticker  ceo  revenue_M marketcap_M  \
# 0      INFORMATION TECHNOLOGY     NaN    NaN  NaN        NaN         NaN
# 1      INFORMATION TECHNOLOGY     NaN    NaN  NaN        NaN         NaN
# 2                         NaN     NaN    NaN  NaN        NaN         NaN
# 3  ENERGY, MINING & UTILITIES     NaN    NaN  NaN        NaN         NaN
# 4  PERSONAL CONSUMER SERVICES     NaN    NaN  NaN        NaN         NaN
#
#    shareprice  id
# 0         NaN   1
# 1         NaN   2
# 2         NaN   3
# 3         NaN   4
# 4         NaN   5

# %%
B.head()
# Out:
#    Unnamed: 0                   name  \
# 0           0                GROUPON
# 1           1         E-TECHNOLOGIES
# 2           2      YAKSHNA SOLUTIONS
# 3           3  THRU TUBING SOLUTIONS
# 4           4   CLEVELAND CLIFFS INC
#
#                                      headquarter        employees  \
# 0  600 W CHICAGO AVE SUITE 400 CHICAGO, IL 60616   1,001 TO 5,000
# 1                                       AUCKLAND          2 TO 10
# 2                                    HERNDON, VA         11 TO 50
# 3                                  OKLAHOMA CITY        51 TO 200
# 4                                  CLEVELAND, OH  5,001 TO 10,000
#
#                      industry website ticker  ceo  revenue_M marketcap_M  \
# 0      INFORMATION TECHNOLOGY     NaN    NaN  NaN        NaN         NaN
# 1      INFORMATION TECHNOLOGY     NaN    NaN  NaN        NaN         NaN
# 2                         NaN     NaN    NaN  NaN        NaN         NaN
# 3  ENERGY, MINING & UTILITIES     NaN    NaN  NaN        NaN         NaN
# 4  PERSONAL CONSUMER SERVICES     NaN    NaN  NaN        NaN         NaN
#
#    shareprice  id
# 0         NaN   1
# 1         NaN   2
# 2         NaN   3
# 3         NaN   4
# 4         NaN   5

# %%
# Create an overlap blocker in Magellan and apply it to A and B to get the candidate set K1 which is in the format of 
# a dataframe. The "l_out_attrs" and "r_out_attrs" parameters indicate the columns that will be included in K1 from A
# and B respectively.
ob = em.OverlapBlocker()
K1 = ob.block_tables(A, B, 'name', 'name', 
                     l_output_attrs=['name', 'headquarter', 'employees', 'industry', 'website', 'ticker', 'ceo', 'revenue_M', 'marketcap_M', 'shareprice'], 
                     r_output_attrs=['name', 'headquarter', 'employees', 'industry', 'website', 'ticker', 'ceo', 'revenue_M', 'marketcap_M', 'shareprice'], 
                     overlap_size=2)
# Out:
# 0% [##############################] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:24

# %%
K1.head()
# Out:
#    _id  ltable_id  rtable_id                ltable_name  \
# 0    0          3          3          YAKSHNA SOLUTIONS
# 1    1          4          4      THRU TUBING SOLUTIONS
# 2    2          5          5       CLEVELAND CLIFFS INC
# 3    3          8          8  MATHIS BROTHERS FURNITURE
# 4    4          9          9      IVYTECH SOLUTIONS INC
#
#         ltable_headquarter ltable_employees             ltable_industry  \
# 0              HERNDON, VA         11 TO 50                         NaN
# 1            OKLAHOMA CITY        51 TO 200  ENERGY, MINING & UTILITIES
# 2            CLEVELAND, OH  5,001 TO 10,000  PERSONAL CONSUMER SERVICES
# 3  OKLAHOMA CITY, OKLAHOMA   1,001 TO 5,000          RETAIL & WHOLESALE
# 4                      NaN              NaN                         NaN
#
#   ltable_website ltable_ticker ltable_ceo  ...                rtable_name  \
# 0            NaN           NaN        NaN  ...          YAKSHNA SOLUTIONS
# 1            NaN           NaN        NaN  ...      THRU TUBING SOLUTIONS
# 2            NaN           NaN        NaN  ...       CLEVELAND CLIFFS INC
# 3            NaN           NaN        NaN  ...  MATHIS BROTHERS FURNITURE
# 4            NaN           NaN        NaN  ...      IVYTECH SOLUTIONS INC
#
#         rtable_headquarter  rtable_employees             rtable_industry  \
# 0              HERNDON, VA          11 TO 50                         NaN
# 1            OKLAHOMA CITY         51 TO 200  ENERGY, MINING & UTILITIES
# 2            CLEVELAND, OH   5,001 TO 10,000  PERSONAL CONSUMER SERVICES
# 3  OKLAHOMA CITY, OKLAHOMA    1,001 TO 5,000          RETAIL & WHOLESALE
# 4                      NaN               NaN                         NaN
#
#   rtable_website rtable_ticker rtable_ceo rtable_revenue_M rtable_marketcap_M  \
# 0            NaN           NaN        NaN              NaN                NaN
# 1            NaN           NaN        NaN              NaN                NaN
# 2            NaN           NaN        NaN              NaN                NaN
# 3            NaN           NaN        NaN              NaN                NaN
# 4            NaN           NaN        NaN              NaN                NaN
#
#   rtable_shareprice
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
#
# [5 rows x 23 columns]

# %%
len(K1)
# Out:
# 3376732

# %%
# Create a new overlap blocker to remove pairs from K1 that have no common word in "Artist_Name".
K1 = ob.block_candset(K1, 'employees', 'employees', overlap_size=1)
len(K1)

#compare.string('name', 'name', label="name")
#compare.exact('employees', 'employees', label='employees')
#compare.string('website', 'website', method='jarowinkler', label="website")
#compare.string('ticker', 'ticker', method='jarowinkler', label="ticker")
#compare.string('ceo', 'ceo', method='jarowinkler', label="ceo")
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/py_entitymatching/blocker/overlap_blocker.py:615: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   table[overlap_attr] = values
# 0% [##############################] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:13
# 258433

# %%
K1.head()
# Out:
#      _id  ltable_id  rtable_id                 ltable_name  \
# 0      0          3          3           YAKSHNA SOLUTIONS
# 1      1          4          4       THRU TUBING SOLUTIONS
# 2      2          5          5        CLEVELAND CLIFFS INC
# 3      3          8          8   MATHIS BROTHERS FURNITURE
# 152  152         17         17  CLEVELAND STATE UNIVERSITY
#
#           ltable_headquarter ltable_employees             ltable_industry  \
# 0                HERNDON, VA         11 TO 50                         NaN
# 1              OKLAHOMA CITY        51 TO 200  ENERGY, MINING & UTILITIES
# 2              CLEVELAND, OH  5,001 TO 10,000  PERSONAL CONSUMER SERVICES
# 3    OKLAHOMA CITY, OKLAHOMA   1,001 TO 5,000          RETAIL & WHOLESALE
# 152                CLEVELAND     501 TO 1,000                   EDUCATION
#
#     ltable_website ltable_ticker ltable_ceo  ...                 rtable_name  \
# 0              NaN           NaN        NaN  ...           YAKSHNA SOLUTIONS
# 1              NaN           NaN        NaN  ...       THRU TUBING SOLUTIONS
# 2              NaN           NaN        NaN  ...        CLEVELAND CLIFFS INC
# 3              NaN           NaN        NaN  ...   MATHIS BROTHERS FURNITURE
# 152            NaN           NaN        NaN  ...  CLEVELAND STATE UNIVERSITY
#
#           rtable_headquarter  rtable_employees             rtable_industry  \
# 0                HERNDON, VA          11 TO 50                         NaN
# 1              OKLAHOMA CITY         51 TO 200  ENERGY, MINING & UTILITIES
# 2              CLEVELAND, OH   5,001 TO 10,000  PERSONAL CONSUMER SERVICES
# 3    OKLAHOMA CITY, OKLAHOMA    1,001 TO 5,000          RETAIL & WHOLESALE
# 152                CLEVELAND      501 TO 1,000                   EDUCATION
#
#     rtable_website rtable_ticker rtable_ceo rtable_revenue_M  \
# 0              NaN           NaN        NaN              NaN
# 1              NaN           NaN        NaN              NaN
# 2              NaN           NaN        NaN              NaN
# 3              NaN           NaN        NaN              NaN
# 152            NaN           NaN        NaN              NaN
#
#     rtable_marketcap_M rtable_shareprice
# 0                  NaN               NaN
# 1                  NaN               NaN
# 2                  NaN               NaN
# 3                  NaN               NaN
# 152                NaN               NaN
#
# [5 rows x 23 columns]

# %%
# Take a sample of 500 pairs from the candidate set.
sample = em.sample_table(K1, 20)

# %%
# Label the sample S in a GUI. Enter 1 for match and 0 for non-match.
gold = em.label_table(sample, 'gold')
# Out:
# WARNING:py_entitymatching.utils.catalog_helper:Column name (gold) is not present in dataframe
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-aa737d42c996> in <module>
#       1 # Label the sample S in a GUI. Enter 1 for match and 0 for non-match.
# ----> 2 gold = em.label_table(sample, 'gold')
#
# /opt/anaconda3/lib/python3.8/site-packages/py_entitymatching/labeler/labeler.py in label_table(table, label_column_name, verbose)
#      70
#      71     from py_entitymatching.gui.table_gui import edit_table
# ---> 72     edit_table(labeled_table)
#      73
#      74     # Post process the labeled table: validate whether the labels contain
#
# /opt/anaconda3/lib/python3.8/site-packages/py_entitymatching/gui/table_gui.py in edit_table(table, show_flag)
#      92             inp = table.iat[i, j]
#      93             val = _cast_val(val, inp)
# ---> 94             table.set_value(idxv[i], cols[j], val)
#      95
#      96
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'set_value'

# %%
result.to_csv("alignedSchemas/gold.csv")
